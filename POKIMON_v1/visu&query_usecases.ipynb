# %% [markdown]
# # Notebook to query and visualize POKIMON instances

# %%
# import the vis package
from pckg.ontovis import *
import os

# %%
# define Colors for types of instances
color_map = {
    # ICEs
"POK:Semantic_Content_Entity": "#5D7A8C",      
"POK:Depiction_Content_Entity": "#188dd6",   
"POK:Proposition_Content_Entity": "#188dd6",      
"POK:Figurative_Content_Entity": "#188dd6",     

"POK:Algorithm": "#4998c9",     
"POK:Action_Specification": "#5d94b7",     
"POK:Objective_Specification": "#5d94b7",     
"POK:Interpretation_Process": "#45ae9a",     
"POK:Estimation_Process": "#45ae9a",     
"POK:Evaluation_Process": "#45ae9a",     
"POK:Decision_Process": "#45ae9a",     



"POK:Conceptual_Geological_Model": "#8bcc55",      
"POK:Space_Time_Geological_Model": "#6fcc55",     
"POK:Action_Specification": "#1780D6", 


    # Geoentities
"POK:Geological_Unit" :  "#ccb655",  
"POK:Lithology":  "#ccb655",  
"POK:Spatial_Location":  "#ccb655",  
"POK:Temporal_Location":  "#ccb655",  
"POK:Fault":  "#ccb655",  
"POK:Rock_Body":  "#ccb655",  
"POK:Rock_Body_Boundary":  "#ccb655",  
"POK:Fold":  "#ccb655",  
"POK:Inter_Limb_Angle":  "#ccb655",  



# others 

"POK:Origin":  "#EC51F4",
"POK:Interpreted_Origin":  "#EC51F4",
"POK:Evaluation":  "#EC51F4",
"POK:Decision":  "#EC51F4",
"POK:Norm":  "#F4519A",
"POK:Constraint":  "#F4519A",
"POK:Geological_Law":  "#F4519A",


"POK:Interpretaton_Situatiion": "#8B9095",
"POK:Part":  "#8B9095",

"Unknown":  "#8B9095",
}

# some generic paramters for the html figures
html_kwargs = {'edge_color' : 'black', 'size_node' : 80,
                'edge_font_size' : 12 , 'node_font_location' : 0, 
                'edge_length':220 , 'node_font_size' : 14,
                'static_layout':False, 
                'node_shape': "box"}
# output folder
output_folder = r'.\html_sparql_outputs'  # update if needed

# %%
# remidner for querries structure as the network graph module is senstive to the sparql structure (e.g., it does not support rdfs:subclasses)
# for exhaustive querying, use a dedicated sparql tool

POKI = Namespace("http://www.POKIMON#")

general_querry_structure = """

PREFIX poki: <http://www.POKIMON#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type poki:Algorithm .

  {
    # ?subject poki:is_About ?object1 .
    # ?object1 rdf:type poki:Planned_Process .
  }
  FILTER EXISTS {
    # ?subject poki:has_Part ?object2 .
    # ?object2 rdf:type poki:Action_Specification .
  }

  {
    # ?subject poki:is_About ?object .
    BIND(poki:is_About AS ?predicate)
  }
  UNION
  {
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
}

"""

# %% [markdown]
# ## Use case 3

# %%
# import the use_case_1 
## ensure to have the ontology  as an rdf/xml file
pokimon_vis_sitauations = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_3_situations.owl', ], color_map_instance = color_map)

pokimon_vis_iter_1 = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_3_iteration_1.owl', ], color_map_instance = color_map)

pokimon_vis_final = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_3_final_geomodel.owl', 
                                                 r'.\examples\pokimon_use_case_3_iteration_1.owl',], color_map_instance = color_map)

pokimon_vis_process = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_3_processes.owl', 
                                                   r'.\examples\pokimon_use_case_3_final_geomodel.owl',
                                                   r'.\examples\pokimon_use_case_3_iteration_1.owl', 
                                                   r'.\examples\pokimon_use_case_3_situations.owl',], color_map_instance = color_map)

pokimon_vis_norm = OntoVis( ontologies_pathes= [
                                                   #r'.\examples\pokimon_use_case_3_processes.owl', 
                                                   r'.\examples\pokimon_use_case_3_final_geomodel.owl',
                                                   #r'.\examples\pokimon_use_case_3_iteration_1.owl', 
                                                   #r'.\examples\pokimon_use_case_3_situations.owl',
                                                   r'.\examples\pokimon_use_case_3_norms.owl',], color_map_instance = color_map)

# %%
# use case 3 querry all instances

query_3_all_instances = """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?class .
  #?object rdf:type ?class2 .
  # ?subject ?predicate ?object .
}
"""

# use case 3 querry instances of geomodels (conceptual and space time)


query_3_situations= """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?Interpretation_Situation .
  {
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)}
}
"""

query_3_iter1= """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:explains ?object .
    BIND(poki:explains AS ?predicate)
  }
  
  UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
   UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Origin ?object .
    BIND(poki:has_Origin AS ?predicate)
  }
  UNION
  {
    # ?subject poki:is_Hosted_By ?object .
    BIND(poki:is_Hosted_By AS ?predicate)
  }
}
"""


query_3_final_geom =  """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:is_Prescribed_By ?object .
    BIND(poki:is_Prescribed_By AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:explains ?object .
    BIND(poki:explains AS ?predicate)
  }
  
  UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
   UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Origin ?object .
    BIND(poki:has_Origin AS ?predicate)
  }
}
"""


query_3_process= """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  {
    VALUES ?targetClass { poki:Interpretation_Process poki:Estimation_Process poki:Evaluation_Process poki:Decision_Process }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Interpretation_Process poki:Estimation_Process poki:Evaluation_Process poki:Decision_Process }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:is_Prescribed_By ?object .
    BIND(poki:is_Prescribed_By AS ?predicate)
  }
   UNION
  {
    VALUES ?targetClass { poki:Interpretation_Process poki:Estimation_Process poki:Evaluation_Process poki:Decision_Process }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Input ?object .
    BIND(poki:has_Input AS ?predicate)
  }
   UNION
  {
    VALUES ?targetClass { poki:Interpretation_Process poki:Estimation_Process poki:Evaluation_Process poki:Decision_Process }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Output ?object .
    BIND(poki:has_Output AS ?predicate)
  }
  UNION
  {
    # ?subject rdf:type poki:Algorithm .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
}
"""


query_3_norm =  """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:satisfies ?object .
    BIND(poki:satisfies AS ?predicate)
  }
   UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:contradicts ?object .
    BIND(poki:contradicts AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:explains ?object .
    BIND(poki:explains AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Evaluation poki:Decision }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:inheres_In ?object .
    BIND(poki:inheres_In AS ?predicate)
  }  

  UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
   UNION
  {
    # ?subject rdf:type poki:Fold .
    # ?subject poki:has_Quality ?object .
    BIND(poki:has_Quality AS ?predicate)
  }
  UNION
  {
    # ?subject poki:has_Value ?object .
    BIND(poki:has_Value AS ?predicate)
  }
}
"""

# %%
#generate the graphes as html files 
# ensure the directory for outputs is created

#pokimon_vis_sitauations.generate_html_from_network_graph(query_3_all_instances, output_html_path= os.path.join(output_folder, 'UC3_all_instances_situations.html'),   **html_kwargs )
#pokimon_vis_sitauations.generate_html_from_network_graph(query_3_situations, output_html_path= os.path.join(output_folder, 'UC3_situations.html'),  **html_kwargs)


#pokimon_vis_iter_1.generate_html_from_network_graph(query_3_all_instances, output_html_path= os.path.join(output_folder, 'UC3_all_instances_iter_1.html'),  **html_kwargs  )
#pokimon_vis_iter_1.generate_html_from_network_graph(query_3_iter1, output_html_path= os.path.join(output_folder, 'UC3_iter1.html'),  **html_kwargs  )


#pokimon_vis_final.generate_html_from_network_graph(query_3_all_instances, output_html_path= os.path.join(output_folder, 'UC3_all_instances_final.html'),  **html_kwargs )
#pokimon_vis_final.generate_html_from_network_graph(query_3_final_geom, output_html_path= os.path.join(output_folder, 'UC3_final_geom.html'), **html_kwargs )

#pokimon_vis_process.generate_html_from_network_graph(query_3_all_instances, output_html_path= os.path.join(output_folder, 'UC3_all_instances_process.html'),  **html_kwargs  )
#pokimon_vis_process.generate_html_from_network_graph(query_3_process, output_html_path= os.path.join(output_folder, 'UC3_process.html'), **html_kwargs )

#pokimon_vis_norm.generate_html_from_network_graph(query_3_all_instances, output_html_path= os.path.join(output_folder, 'UC3_all_instances_norm.html'),  **html_kwargs  )
pokimon_vis_norm.generate_html_from_network_graph(query_3_norm, output_html_path= os.path.join(output_folder, 'UC3_normmm.html'), **html_kwargs )

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# ## Use case 2

# %%
# import the use_case_1 
## ensure to have the ontology  as an rdf/xml file
pokimon_vis = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_2.owl', ], color_map_instance = color_map)

# %%
# use case 2 querry all instances

query_2_all_instances = """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?class .
  #?object rdf:type ?class2 .
  # ?subject ?predicate ?object .
}
"""

# use case 1 querry instances of geomodels (conceptual and space time)


query_2_geomodels= """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
  # ?subject rdf:type ?targetClass .

  {
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    # ?subject poki:simplifies ?object .
    BIND(poki:simplifies AS ?predicate)
  }
  UNION
  {
    # ?subject poki:details ?object .
    BIND(poki:details AS ?predicate)
  }
 }
  """
#############
query_2_geomodels_and_comp= """

PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object 
WHERE {
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:simplifies ?object .
    BIND(poki:simplifies AS ?predicate)
  }
  UNION
  {
    VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
    # ?subject rdf:type ?targetClass .
    # ?subject poki:details ?object .
    BIND(poki:details AS ?predicate)
  }
  UNION
  {
    # ?subject rdf:type poki:Semantic_Content_Entity .
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
}
"""
# use case 1 querry instances of semantic components of the semantic content entities of geomodels


query_2_smnt_compo = """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?Semantic_Content_Entity .
  {
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
}
  """

# %%
#generate the graphes as html files 
# ensure the directory for outputs is created

pokimon_vis.generate_html_from_network_graph(query_2_all_instances, output_html_path= os.path.join(output_folder, 'UC2_all_instances.html'),  **html_kwargs )
pokimon_vis.generate_html_from_network_graph(query_2_geomodels, output_html_path= os.path.join(output_folder, 'UC2_geomodels.html'),  **html_kwargs)
pokimon_vis.generate_html_from_network_graph(query_2_geomodels_and_comp, output_html_path= os.path.join(output_folder, 'UC2_geomodels&compo.html'),  **html_kwargs )
pokimon_vis.generate_html_from_network_graph(query_2_smnt_compo,output_html_path= os.path.join(output_folder, 'UC2_semnt_compo.html'),  **html_kwargs )

# %% [markdown]
# stop

# %% [markdown]
# ## Use case 1

# %%
# import the use_case_1 
## ensure to have the ontology  as an rdf/xml file
pokimon_vis = OntoVis( ontologies_pathes= [r'.\examples\pokimon_use_case_1.owl', ], color_map_instance = color_map)

# %%
# use case 1 querry all instances

query_1_all_instances = """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?class .
  #?object rdf:type ?class2 .
  # ?subject ?predicate ?object .
}
"""

# use case 1 querry instances of geomodels (conceptual and space time)


query_1_geomodels= """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  VALUES ?targetClass { poki:Conceptual_Geological_Model poki:Space_Time_Geological_Model }
  # ?subject rdf:type ?targetClass .

  {
    # ?subject poki:has_Part ?object .
    BIND(poki:has_Part AS ?predicate)
  }
  UNION
  {
    # ?subject poki:satisfies ?object .
    BIND(poki:satisfies AS ?predicate)
  }
}
  """


# use case 1 querry instances of semantic components of the semantic content entities of geomodels


query_1_smnt_compo = """
PREFIX poki: <http://www.POKIMON#POK:>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT DISTINCT ?subject ?predicate ?object
WHERE {
  # ?subject rdf:type ?Semantic_Content_Entity .
  {
    # ?subject poki:has_Semantic_Component ?object .
    BIND(poki:has_Semantic_Component AS ?predicate)
  }
}
  """

# %%
#generate the graphes as html files 
# ensure the directory for outputs is created

pokimon_vis.generate_html_from_network_graph(query_1_all_instances, output_html_path= os.path.join(output_folder, 'UC1_all_instances.html'),   **html_kwargs  )
pokimon_vis.generate_html_from_network_graph(query_1_geomodels, output_html_path= os.path.join(output_folder, 'UC1_geomodels.html'),  **html_kwargs )
pokimon_vis.generate_html_from_network_graph(query_1_smnt_compo,output_html_path= os.path.join(output_folder, 'UC1_semnt_compo.html'),   **html_kwargs )
